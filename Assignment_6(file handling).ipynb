# %% [markdown]
# # Theory Questions

# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?
# - interpreted languages read the code line by line and compiled languages use compiler which complie all the lines of code at the run time.
#
# 2. What is exception handling in Python?
# - exception handling is the method to detect and manage errors that occur while the programm is running so that programm will not crash unexpectedly.
#
# 3. What is the purpose of the finally block in exception handling ?
# -  finally block is used as a closing block of code it runs regardless of the error occurence or not.
#
# 4. What is logging in Python?
# - Logging in Python is a way to record important information about events that occur while a program is running. It helps developers track the flow of the program, debug issues, and understand problems without stopping the program or using print statements everywhere.
#
# 5. What is the significance of the __del__ method in Python?
# - In Python, the __del__ method is a destructor method that is automatically called when an object is about to be destroyed (i.e., when the object’s reference count reaches zero, or when the program ends). It is used to perform cleanup operations such as closing files, releasing memory, or disconnecting from a database.
#
# 6. What is the difference between import and from ... import in Python?
# - Both are used to call a module but works diffrently as import is used to call a complete module and must be called use as prefix and from is used to call the specific object like func,method from a module.
#
# 7. How can you handle multiple exceptions in Python?
# - there are multiple ways to handel errors.
#  - using multiple except blocks
#  - using single except block.
#
# 8. What is the purpose of the with statement when handling files in Python?
# - The with statement in Python is used to manage resources like files, ensuring that they are properly opened and automatically closed after their usage—even if an error occurs. It is most commonly used when working with files.
#
# 9. What is the difference between multithreading and multiprocessing?
# - Multithreading involves running multiple threads within the same process, where all threads share the same memory space. It is most effective for I/O-bound tasks such as handling user requests, reading and writing files, or performing network operations, because the Global Interpreter Lock (GIL) in Python allows only one thread to execute Python code at a time, limiting true parallel execution
# - multiprocessing uses multiple independent processes, each with its own separate memory space, enabling true parallelism without being restricted by the GIL. This makes multiprocessing ideal for CPU-bound tasks like heavy computations, data processing, image rendering, or machine learning operations.
#
# 10. What are the advantages of using logging in a program ?
# - Logging provides a systematic way to record events and errors during program execution.
# It helps in debugging and identifying issues without stopping the program.
# Logs can be saved to files for later analysis and monitoring.
# It offers different log levels and makes applications easier to maintain and track.
#
# 11. What is memory management in Python?
# - Memory management in Python refers to how Python handles the allocation and deallocation of memory automatically during program execution.
# It uses a private heap to store objects and the Python memory manager allocates space as needed.
# Python also includes garbage collection to free up memory by removing unused objects.
# This automatic process makes memory usage efficient and reduces the chance of memory leaks.
#
# 12. What are the basic steps involved in exception handling in Python ?
#
# - The basic steps in exception handling begin with placing risky code inside a try block.If an error occurs, it is caught by an except block where the exception is handled.Optionally, an else block runs if no exception occurs.
# Finally, a finally block executes cleanup code whether an exception occurred or not.
#
# 13. Why is memory management important in Python ?
#
# - Memory management is important in Python because it ensures efficient use of system memory.It prevents memory leaks and keeps programs running smoothly.
# Automatic garbage collection frees unused memory to optimize performance.
# Good memory management improves reliability and scalability of applications.
#
# 14. What is the role of try and except in exception handling?
#
# - try block contain the risky part of the code and except block actually handel the error if occured.
#
# 15.  How does Python's garbage collection system work ?
# - Python’s garbage collection system automatically frees memory by removing objects that are no longer in use.
# It primarily uses reference counting, where each object keeps track of how many references point to it.
# When the reference count reaches zero, the memory is immediately deallocated.
# Additionally, Python uses a cyclic garbage collector to detect and clean up circular references that reference counting alone cannot resolve.
#
# 16. What is the purpose of the else block in exception handling ?
#
# - The else block in exception handling is used to run code only if no exception occurs in the try block.
# It helps separate normal execution from error-handling code.
# The else block improves readability and keeps logic clean.
# It executes right after the try block if everything runs successfully without errors.
#
# 17. What are the common logging levels in Python ?
#
# - The common logging levels in Python are DEBUG, INFO, WARNING, ERROR, and CRITICAL.
# DEBUG is used for detailed diagnostic information.
# INFO confirms that things are working as expected.
# WARNING, ERROR, and CRITICAL indicate increasing levels of seriousness for problems.
#
# 18. What is the difference between os.fork() and multiprocessing in Python?
# - os.fork() directly creates a child process by duplicating the current process, and it works only on Unix-based systems like Linux and macOS. It provides low-level control but requires more manual handling of communication and synchronization.
# - the multiprocessing module is a high-level Python library that works on all major platforms including Windows, providing easy process creation and built-in support for communication through queues and pipes. It is safer, more portable, and simpler to use for parallel processing tasks.
#
# 19. What is the importance of closing a file in Python ?
# - Closing a file in Python is important because it releases the system resources associated with the file.
# It ensures that all data is properly saved and written before the program ends.
# Not closing a file can lead to data corruption or loss.
# It also helps avoid memory leaks and improves program performance.
#
# 20. What is the difference between file.read() and file.readline() in Python?
#
# - file.read() reads the entire file content at once and returns it as a single string.
#
# - file.readline() reads only one line at a time from the file.
#
# - file.read() is useful when you need the complete file content, but it can use more memory for large files.
#
# - file.readline() is better for processing large files line by line without loading everything into memory.
#
# 21. What is the logging module in Python used for ?
# - The logging module in Python is used to record messages about the execution of a program.
# It helps developers track errors, warnings, and important events while the program runs.
# It allows logs to be saved to files or displayed on the console for debugging and monitoring.
# Using logging makes programs easier to diagnose, maintain, and analyze.
#
# 22. What is the os module in Python used for in file handling?
#
# - The os module in Python is used to interact with the operating system for file and directory operations.
# It allows tasks like creating, deleting, renaming, and navigating directories.
# You can also check file existence, permissions, and paths.
# Overall, it helps manage files and folders at the system level easily.
#
# 23.  What are the challenges associated with memory management in Python ?
# - Some challenges associated with memory management in Python include handling reference cycles, where objects reference each other and delay garbage collection.
# The Global Interpreter Lock (GIL) can limit true parallelism and affect performance with multithreading.
# Managing memory usage for large data structures can become difficult and may lead to high memory consumption.
# Unintentional memory leaks can occur if references are not released properly or external resources aren’t closed.
#
# 24. How do you raise an exception manually in Python ?
# - You can raise an exception manually in Python using the raise keyword.
# This is useful when you want to intentionally trigger an error based on a specific condition.
#
# 25. Why is it important to use multithreading in certain applications ?
# - Multithreading is important in certain applications because it allows multiple tasks to run concurrently within the same program, improving performance and responsiveness.
# It is especially useful for I/O-bound operations like file handling, network requests, or user interface activities where tasks often wait for external resources.
# Multithreading helps utilize waiting time efficiently, keeping the application active instead of idle.
# It improves user experience, enables real-time processing, and makes programs run more smoothly without freezing.

# %% [markdown]
# # Practical Questions

# %%
# 1. How can you open a file for writing in Python and write a string to it?
with open("example.txt", "w") as file:
    file.write("Hello, Python!")

# %%
# 2. Write a Python program to read the contents of a file and print each line?
with open("example.txt", "r") as file:
    for line in file:
        print(line, end="")
# Out:
# This text will be added at the end.
# This text will be added at the end.

# %%
# 3. How would you handle a case where the file doesn't exist while trying to open it for reading?

try:
    with open("example.txt", "r") as file:
        print(file.read())
except FileNotFoundError:
    print("Error: The file does not exist.")
# Out:
# This text will be added at the end.
# This text will be added at the end.

# %%
# 4.  Write a Python script that reads from one file and writes its content to another file ?
with open("source.txt", "r") as src:
    content = src.read()

with open("destination.txt", "w") as dest:
    dest.write(content)

print("File copied successfully.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1854727554.py in <cell line: 0>()
#       1 # 4.  Write a Python script that reads from one file and writes its content to another file ?
# ----> 2 with open("source.txt", "r") as src:
#       3     content = src.read()
#       4
#       5 with open("destination.txt", "w") as dest:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'source.txt'

# %%
# 5. How would you catch and handle division by zero error in Python ?
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Cannot divide by zero!")
# Out:
# Error: Cannot divide by zero!

# %%
# 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs?
import logging

logging.basicConfig(filename="error.log", level=logging.ERROR)

# %%
# 7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?
import logging

logging.basicConfig(level=logging.DEBUG)

logging.info("This is an INFO message")
logging.warning("This is a WARNING message")
logging.error("This is an ERROR message")
# Out:
# WARNING:root:This is a WARNING message
# ERROR:root:This is an ERROR message

# %%
# 8. Write a program to handle a file opening error using exception handling

try:
    file = open("nonexistent_file.txt", "r")
    print(file.read())
    file.close()
except FileNotFoundError:
    print("Error: The file could not be opened because it does not exist.")
# Out:
# Error: The file could not be opened because it does not exist.

# %%
# 9. How can you read a file line by line and store its content in a list in Python?
with open("example.txt", "r") as file:
    lines = file.readlines()

print(lines)
# Out:
# ['This text will be added at the end.\n']

# %%
# 10. How can you append data to an existing file in Python?
with open("example.txt", "a") as file:
    file.write("This text will be added at the end.\n")

# %%
# 11. F Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't existF
my_dict = {"name": "Amit", "age": 22}

try:
    value = my_dict["address"]
    print(value)
except KeyError:
    print("Error: The specified key does not exist in the dictionary.")
# Out:
# Error: The specified key does not exist in the dictionary.

# %%
# 12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions?

try:
    num = int(input("Enter a number: "))
    result = 10 / num
    print("Result:", result)

except ValueError:
    print("Error: Please enter a valid integer.")

except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")

except Exception as e:
    print("An unexpected error occurred:", e)
# Out:
# Enter a number: 23
# Result: 0.43478260869565216

# %%
# 13. How would you check if a file exists before attempting to read it in Python?
import os

filename = "example.txt"

if os.path.exists(filename):
    with open(filename, "r") as file:
        print(file.read())
else:
    print("File does not exist.")
# Out:
# This text will be added at the end.

# %%
# 14. Write a program that uses the logging module to log both informational and error messages

import logging

logging.basicConfig(filename="app.log",
                    level=logging.DEBUG,
                    format="%(asctime)s - %(levelname)s - %(message)s")

logging.info("Program has started successfully.")

try:
    result = 10 / 0
except ZeroDivisionError:
    logging.error("Error: Attempted division by zero!")

logging.info("Program finished execution.")
# Out:
# ERROR:root:Error: Attempted division by zero!

# %%
#15. Write a Python program that prints the content of a file and handles the case when the file is empty
try:
    with open("example.txt", "r") as file:
        content = file.read()
        if content.strip() == "":
            print("The file is empty.")
        else:
            print("File Content:")
            print(content)
except FileNotFoundError:
    print("Error: The file does not exist.")
# Out:
# File Content:
# This text will be added at the end.

# %%
# 16.  Demonstrate how to use memory profiling to check the memory usage of a small program

import tracemalloc

def make_list():
    return [i for i in range(100000)]

tracemalloc.start()
before = tracemalloc.get_traced_memory()

data = make_list()

after = tracemalloc.get_traced_memory()
tracemalloc.stop()

print(f"Current: {after[0]} bytes")
print(f"Peak:    {after[1]} bytes")
print(f"Used in function: {after[0] - before[0]} bytes")
# Out:
# Current: 3993741 bytes
# Peak:    4012197 bytes
# Used in function: 3992768 bytes

# %%
# 17.  Write a Python program to create and write a list of numbers to a file, one number per line.

numbers = [1, 2, 3, 4, 5]

with open("numbers.txt", "w") as file:
    for num in numbers:
        file.write(str(num) + "\n")

print("Numbers written to file successfully.")
# Out:
# Numbers written to file successfully.

# %%
# 18.  How would you implement a basic logging setup that logs to a file with rotation after 1MB?
import logging
from logging.handlers import RotatingFileHandler

logger = logging.getLogger("my_logger")
logger.setLevel(logging.INFO)

handler = RotatingFileHandler(
    "app.log",
    maxBytes=1_000_000,
    backupCount=3
)

formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
handler.setFormatter(formatter)

logger.addHandler(handler)

logger.info("This is an info message")
logger.error("This is an error message")
# Out:
# INFO:my_logger:This is an info message
# ERROR:my_logger:This is an error message

# %%
# 19. Write a program that handles both IndexError and KeyError using a try-except block.
try:
    my_list = [10, 20, 30]
    my_dict = {"name": "Amit"}

    print(my_list[5])
    print(my_dict["age"])
except IndexError:
    print("Error: List index out of range.")

except KeyError:
    print("Error: The specified key is not found in the dictionary.")
# Out:
# Error: List index out of range.

# %%
#20.  How would you open a file and read its contents using a context manager in Python

with open("example.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# This text will be added at the end.

# %%
# 21.  Write a Python program that reads a file and prints the number of occurrences of a specific word.
word_to_find = "python"

with open("example.txt", "r") as file:
    content = file.read().lower()
    count = content.count(word_to_find.lower())

print(f"The word '{word_to_find}' occurs {count} times in the file.")
# Out:
# The word 'python' occurs 0 times in the file.

# %%
# 22. How can you check if a file is empty before attempting to read its content?
import os

filename = "example.txt"

if os.path.getsize(filename) == 0:
    print("The file is empty.")
else:
    with open(filename, "r") as file:
        print(file.read())
# Out:
# This text will be added at the end.

# %%
# 23.  Write a Python program that writes to a log file when an error occurs during file handling

import logging

logging.basicConfig(filename="file_error.log",
                    level=logging.ERROR,
                    format="%(asctime)s - %(levelname)s - %(message)s")

try:
    with open("nonexistent.txt", "r") as file:
        data = file.read()
        print(data)

except FileNotFoundError:
    logging.error("File handling error: The file does not exist.")
    print("An error occurred. Check the log file for details.")
# Out:
# ERROR:root:File handling error: The file does not exist.
# An error occurred. Check the log file for details.
