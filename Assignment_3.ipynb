# %% [markdown]
# #THEORY QUESTIONS

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#
#  - function is a block of code that perfrom some computation and return the result and can be accessed anywhere in the programm.
#  ex - def sum(a,b): return a+b
#
#
#  - method is also a function but it is defined in the class that must be call by object. inbuilt functions like upper,lower,append etc.
# ex -
# name = "amit"
# print(name.upper())
#
# 2. Explain the concept of function arguments and parameters in Python.
#
# - arguments are the actual values passed while calling a function.these value refer to the parameters of the function passed.
# ex - sum(2,3).
# - Parameter is the variable name written in function definition.
# ex - sum(a,b)
#
# 3. What are the different ways to define and call a function in Python?
# - Function can be defined with normal parameters, default parameters, positional arguments, keyword arguments, *args, **kwargs and lambda function. It can be called using positional calling, keyword calling or mixed calling. ex -
#
# 4. What is the purpose of the `return` statement in a Python function?
#  - t gives the output of the function.
#
#  - It stops the function immediately.
#
#  - It can return any data type (number, string, list, tuple, dictionary, object etc.)
#
#  - A function can also return multiple values (Python allows that as tuple)
#
#    - ex - def square(n):return n**2
#
# 5. What are iterators in Python and how do they differ from iterables?
#  - iterator is an object that representing the stram of data and return the data one by one.while iterable is a python object/sequential str/data striucture that is capable of returning its member one at a time
#
# 6. Explain the concept of generators in Python and how they are defined.
# - generators are used to generate the value one by one instead of doing in one go.
#
# - defnined exactly like regular function but instead of return statement use yeild to make the function iterable.
#
# 7. What are the advantages of using generators over regular functions?
# - Memory Efficient -
# They generate values only when needed (lazy evaluation).
# Example: generating first 1 million numbers won’t require storing 1 million items.
#
# - Better Performance -
# They do not compute everything upfront → faster in cases where all values are not needed.
#
#  - Infinite Sequences possible -
# You can create infinite sequences easily (like fibonacci, streaming logs, sensor data).
#
# 8. What is a lambda function in Python and when is it typically used?
# - A lambda function in Python is a small anonymous function which is defined without using def keyword.It is written using the keyword lambda
# - it is used when we want to write the small function and no need to write return statement. ex - square = lambda X:X**2.
#
# 9. Explain the purpose and usage of the `map()` function in Python.
# - map function is used to iterate over each element of iterable list,tuple,etc.and return new iterator.
#
# ex - nums = [1, 2, 3, 4]
# result = map(lambda x: x * 2, nums)
#
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#   - map() - Applies a function to each item in an iterable and returns transformed values
#   - filter() - filter the elements based on some conditions.
#   - reduce() - it Reduces iterable to a single final value or we can say combine the final result.
#  - ex - print(list(map(lambda x: x*x, nums))), print(list(filter(lambda x: x%2==0, nums))),print(reduce(lambda x,y: x+y, nums)).

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using reduce function on this given list:[47,11,42,13];
#
# Image - [https://drive.google.com/file/d/1zPxlo9CmCUTwv5E08tWyTf33ow62XWeg/view?usp=sharing]

# %% [markdown]
# ##PRACTICAL QUESTIONS

# %%
#1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
def sum_even(lst):
  s = 0
  for i in lst:
    if i%2 ==0:
      s += i
  return s
sum_even([2,3,4,5,6,7,8])
# Out:
# 20

# %%
# 2. Create a Python function that accepts a string and returns the reverse of that string.

def reverse(s):
  return s[::-1]
reverse("amit")
# Out:
# 'tima'

# %%
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

square = map(lambda x:x**2,[1,2,3,4,5])
list(square)
# Out:
# [1, 4, 9, 16, 25]

# %%
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, n):
        if n % i == 0:
            return False
    return True

is_prime(17)
# Out:
# True

# %%
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number ofterms.
def fibo(n):
  a = 0
  b = 1
  for i in range(n):
    yield a
    a,b = b,a+b
# Out:
# <generator object fibo at 0x781ef62d5540>

# %%
f =fibo(5)
next(f)
# Out:
# 0

# %%
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

def power_of_two(n):
    for i in range(n+1):
        yield 2 ** i
power_of_two(5)
# Out:
# <generator object power_of_two at 0x781ef4e54c70>

# %%
# 7. Implement a generator function that reads a file line by line and yields each line as a string.
def read_file_lines(filename):
    with open(filename, "r") as file:
        for line in file:
            yield line.strip()

# %%
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

t = [(4, 10), (2, 5), (9, 1), (7, 3)]
sorted_list = sorted(t, key = lambda x: x[1])
print(sorted_list)
# Out:
# [(9, 1), (7, 3), (2, 5), (4, 10)]

# %%
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
celsius_temps = [0, 10, 20, 30, 40]
fahrenheit_temps = list(map(lambda x: (x * 9/5) + 32, celsius_temps))
print(fahrenheit_temps)
# Out:
# [32.0, 50.0, 68.0, 86.0, 104.0]

# %%
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

text = "Hello World, Python Programming"
vowels = "aeiouAEIOU"
result = "".join(filter(lambda ch: ch not in vowels, text))
print(result)
# Out:
# Hll Wrld, Pythn Prgrmmng

# %%
# 11. Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and theproduct of the price per item and the quantity. The product should be increased by 10,- € if the value of theorder is smaller than 100,00 €.
# Write a Python program using lambda and map.

orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

result = list(map(lambda x: (x[0], x[2] * x[3] if x[2] * x[3] >= 100 else x[2] * x[3] + 10), orders))

print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
